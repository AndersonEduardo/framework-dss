# %%
from dataloader import DataLoader as dl

# %%
data = dl.load_data()

# %%
data['bundles_data_formated']
# Out:
# [{'label': 'Cia',
#   'value': 'context_0',
#   'children': [{'label': 'Entorse-Apresentação-E-Posologia',
#     'value': 'bundle_1',
#     'children': [{'label': '"1 comprimido de 6/6h, conforme sintomas',
#       'value': 'item_2'},
#      {'label': '1 comprimido de 6/6h, conforme sintomas', 'value': 'item_3'},
#      {'label': '1 comprimido de 8/8h', 'value': 'item_4'},
#      {'label': '1 comprimido de 12/12h', 'value': 'item_5'},
#      {'label': '1 comprimido de 6/6h', 'value': 'item_6'},
#      {'label': '1 comprimido de 4/4h, se dor intensa', 'value': 'item_7'},
#      {'label': '1 comprimido de 6/6h, se dor intensa"', 'value': 'item_8'}]},
#    {'label': 'Entorse-Ciap',
#     'value': 'bundle_9',
#     'children': [{'label': '"l77', 'value': 'item_10'},
#      {'label': 'l16', 'value': 'item_11'},
#      {'label': 'k07"', 'value': 'item_12'}]},
#    {'label': 'Entorse-Cid-10',
#     'value': 'bundle_13',
#     'children': [{'label': '"s93.4"', 'value': 'item_14'}]},
# ...

# %%
import requests
from parameters import *

response = requests.get(API_DSSF_BUNDLES)
data = response.json()

# %%
data['response']
# Out:
# {'cia': {'entorse-apresentação-e-posologia': '"1 comprimido de 6/6h, conforme sintomas[LINEBREAK]1 comprimido de 6/6h, conforme sintomas[LINEBREAK]1 comprimido de 8/8h[LINEBREAK]1 comprimido de 12/12h[LINEBREAK]1 comprimido de 6/6h[LINEBREAK]1 comprimido de 4/4h, se dor intensa[LINEBREAK]1 comprimido de 6/6h, se dor intensa"',
#   'entorse-ciap': '"l77[LINEBREAK]l16[LINEBREAK]k07"',
#   'entorse-cid-10': '"s93.4"',
#   'entorse-cipe': '"6.15[LINEBREAK]8.48[LINEBREAK]8.54[LINEBREAK]8.66[LINEBREAK]16.36"',
#   'entorse-encaminhamento': '"fisioterapeuta[LINEBREAK]médico ortopedista e traumatologista"',
#   'entorse-exame': '"radiografia pé[LINEBREAK]radiografia tornozelo"',
#   'entorse-medicamento': '"dipirona 1g[LINEBREAK]paracetamol 750mg[LINEBREAK]diclofenaco sódico 50mg[LINEBREAK]nimesulida 100mg[LINEBREAK]tramadol 50mg[LINEBREAK]tramadol 50mg[LINEBREAK]codeína 7,5mg + paracetamol 500mg"',
# ...

# %%
import pandas as pd

pd.__version__
# Out:
# '2.0.0'
